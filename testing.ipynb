# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

x = pd.read_excel("Artery Tree/sim.xlsx")
a = x[0]


t = np.arange(0, 10, 0.01)
plt.plot(t, a , linewidth=1.0)
#plt.plot(t, b ,  linewidth=1.0)
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.title('EEG WAVE')
# Out:
# Text(0.5, 1.0, 'EEG WAVE')
